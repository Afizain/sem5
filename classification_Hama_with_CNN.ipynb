# %% [markdown]
# # import tools

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import csv

# %% [markdown]
# # Set your dataset directory

# %%
sdir = r'D:\Afi\PROJEK\Semester 5\Web_Aplication_Hama_Detection\Dataset'

# %% [markdown]
# # Load file paths and labels

# %%
filepaths, labels = [], []
classlist = os.listdir(sdir)
for klass in classlist:
    classpath = os.path.join(sdir, klass)
    if os.path.isdir(classpath):
        flist = os.listdir(classpath)
        for f in flist:
            fpath = os.path.join(classpath, f)
            filepaths.append(fpath)
            labels.append(klass)

df = pd.DataFrame({'filepaths': filepaths, 'labels': labels})
print (classlist)
# Out:
# ['hama_belalang', 'hama_ulat', 'sawi_sehat']

# %% [markdown]
# # Split the dataset

# %%
train_split, test_split = 0.7, 0.3
train_df, test_df = train_test_split(df, train_size=train_split, shuffle=True, random_state=123)

# %% [markdown]
# # Set image parameters

# %%
height, width, channels = 224, 224, 3
batch_size = 16
img_size = (height, width)
img_shape = (height, width, channels)

# %% [markdown]
# # Data generators

# %%
datagen = ImageDataGenerator(
    rescale=1.0 / 255,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    brightness_range=[0.5, 1.5]
)

train_gen = datagen.flow_from_dataframe(train_df, x_col='filepaths', y_col='labels', target_size=img_size,
                                        class_mode='categorical', color_mode='rgb', shuffle=True, batch_size=batch_size)

test_gen = datagen.flow_from_dataframe(test_df, x_col='filepaths', y_col='labels', target_size=img_size,
                                      class_mode='categorical', color_mode='rgb', shuffle=False, batch_size=batch_size)
# Out:
# Found 817 validated image filenames belonging to 3 classes.
# Found 351 validated image filenames belonging to 3 classes.

# %% [markdown]
# # Build the model

# %%
model = keras.Sequential([
    # Feature Extraction
    layers.Conv2D(8, (3, 3), padding='same', input_shape=(img_shape), activation='relu', strides=1),
    layers.MaxPooling2D(pool_size=(2, 2)),
    
    layers.Conv2D(16, (3, 3), padding='same', activation='relu', strides=1),
    layers.MaxPooling2D(pool_size=(2, 2)),
    
    layers.Conv2D(32, (3, 3), padding='same', activation='relu', strides=1),
    layers.MaxPooling2D(pool_size=(2, 2)),
    
    layers.Conv2D(64, (3, 3), padding='same', activation='relu', strides=1),
    layers.MaxPooling2D(pool_size=(2, 2)),
    
    layers.Conv2D(128, (3, 3), padding='same', activation='relu', strides=1),
    layers.MaxPooling2D(pool_size=(2, 2)),
    
    layers.Flatten(),
    
    # Fully Connected
    layers.Dense(1568, activation='relu'),
    layers.Dropout(0.1),
    layers.Dense(3, activation='softmax')
    
])

model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 8)       224
#
#  max_pooling2d (MaxPooling2  (None, 112, 112, 8)       0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 16)      1168
#
#  max_pooling2d_1 (MaxPoolin  (None, 56, 56, 16)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 32)        4640
#
#  max_pooling2d_2 (MaxPoolin  (None, 28, 28, 32)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 64)        18496
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 64)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 128)       73856
#
#  max_pooling2d_4 (MaxPoolin  (None, 7, 7, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 1568)              9836064
#
#  dropout (Dropout)           (None, 1568)              0
#
#  dense_1 (Dense)             (None, 3)                 4707
#
# =================================================================
# Total params: 9939155 (37.91 MB)
# Trainable params: 9939155 (37.91 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Train and Test Data

# %%
epochs = 50

# Training without any callbacks
history = model.fit(x=train_gen, epochs=epochs, validation_data=test_gen)

# Save the model manually at the end of training
model.save('New_model2.h5')
# Out:
# Epoch 1/50
# 52/52 [==============================] - 46s 851ms/step - loss: 0.9115 - accuracy: 0.5851 - val_loss: 0.8490 - val_accuracy: 0.6268
# Epoch 2/50
# 52/52 [==============================] - 37s 706ms/step - loss: 0.7095 - accuracy: 0.7026 - val_loss: 0.5821 - val_accuracy: 0.7578
# Epoch 3/50
# 52/52 [==============================] - 36s 700ms/step - loss: 0.6196 - accuracy: 0.7344 - val_loss: 0.5813 - val_accuracy: 0.8006
# Epoch 4/50
# 52/52 [==============================] - 37s 702ms/step - loss: 0.6619 - accuracy: 0.7222 - val_loss: 0.5630 - val_accuracy: 0.7550
# Epoch 5/50
# 52/52 [==============================] - 37s 708ms/step - loss: 0.5615 - accuracy: 0.7662 - val_loss: 0.5692 - val_accuracy: 0.7521
# Epoch 6/50
# 52/52 [==============================] - 39s 756ms/step - loss: 0.4316 - accuracy: 0.8311 - val_loss: 0.4434 - val_accuracy: 0.8120
# Epoch 7/50
# 52/52 [==============================] - 43s 826ms/step - loss: 0.4979 - accuracy: 0.8054 - val_loss: 0.5753 - val_accuracy: 0.7778
# Epoch 8/50
# 52/52 [==============================] - 42s 817ms/step - loss: 0.4638 - accuracy: 0.8237 - val_loss: 0.4720 - val_accuracy: 0.7778
# Epoch 9/50
# 52/52 [==============================] - 53s 1s/step - loss: 0.3964 - accuracy: 0.8335 - val_loss: 0.5033 - val_accuracy: 0.7892
# Epoch 10/50
# 52/52 [==============================] - 44s 836ms/step - loss: 0.4358 - accuracy: 0.8188 - val_loss: 0.4119 - val_accuracy: 0.8234
# Epoch 11/50
# 52/52 [==============================] - 40s 775ms/step - loss: 0.3655 - accuracy: 0.8629 - val_loss: 0.3248 - val_accuracy: 0.8718
# Epoch 12/50
# 52/52 [==============================] - 41s 785ms/step - loss: 0.3579 - accuracy: 0.8543 - val_loss: 0.3449 - val_accuracy: 0.8803
# Epoch 13/50
# 52/52 [==============================] - 42s 813ms/step - loss: 0.3696 - accuracy: 0.8580 - val_loss: 0.4743 - val_accuracy: 0.7806
# Epoch 14/50
# 52/52 [==============================] - 43s 832ms/step - loss: 0.3359 - accuracy: 0.8580 - val_loss: 0.5766 - val_accuracy: 0.7721
# Epoch 15/50
# 52/52 [==============================] - 42s 802ms/step - loss: 0.3541 - accuracy: 0.8531 - val_loss: 0.3646 - val_accuracy: 0.8433
# Epoch 16/50
# 52/52 [==============================] - 42s 803ms/step - loss: 0.3130 - accuracy: 0.8690 - val_loss: 0.5037 - val_accuracy: 0.8262
# Epoch 17/50
# 52/52 [==============================] - 42s 804ms/step - loss: 0.3324 - accuracy: 0.8654 - val_loss: 0.3281 - val_accuracy: 0.8718
# Epoch 18/50
# 52/52 [==============================] - 42s 805ms/step - loss: 0.3636 - accuracy: 0.8629 - val_loss: 0.3341 - val_accuracy: 0.8604
# Epoch 19/50
# 52/52 [==============================] - 42s 811ms/step - loss: 0.3287 - accuracy: 0.8752 - val_loss: 0.3247 - val_accuracy: 0.8604
# Epoch 20/50
# 52/52 [==============================] - 42s 802ms/step - loss: 0.3283 - accuracy: 0.8592 - val_loss: 0.5583 - val_accuracy: 0.8205
# Epoch 21/50
# 52/52 [==============================] - 41s 799ms/step - loss: 0.3107 - accuracy: 0.8752 - val_loss: 0.3057 - val_accuracy: 0.8689
# Epoch 22/50
# 52/52 [==============================] - 42s 803ms/step - loss: 0.3263 - accuracy: 0.8727 - val_loss: 0.4377 - val_accuracy: 0.7892
# Epoch 23/50
# 52/52 [==============================] - 41s 795ms/step - loss: 0.3092 - accuracy: 0.8666 - val_loss: 0.3675 - val_accuracy: 0.8689
# Epoch 24/50
# 52/52 [==============================] - 42s 801ms/step - loss: 0.2399 - accuracy: 0.8984 - val_loss: 0.3343 - val_accuracy: 0.8376
# Epoch 25/50
# 52/52 [==============================] - 42s 801ms/step - loss: 0.2785 - accuracy: 0.8874 - val_loss: 0.3569 - val_accuracy: 0.8519
# Epoch 26/50
# 52/52 [==============================] - 42s 811ms/step - loss: 0.2329 - accuracy: 0.9009 - val_loss: 0.3109 - val_accuracy: 0.8746
# Epoch 27/50
# 52/52 [==============================] - 43s 826ms/step - loss: 0.2413 - accuracy: 0.8911 - val_loss: 0.4333 - val_accuracy: 0.8291
# Epoch 28/50
# 52/52 [==============================] - 43s 825ms/step - loss: 0.2813 - accuracy: 0.8886 - val_loss: 0.2705 - val_accuracy: 0.8775
# Epoch 29/50
# 52/52 [==============================] - 43s 822ms/step - loss: 0.2285 - accuracy: 0.8960 - val_loss: 0.2746 - val_accuracy: 0.8974
# Epoch 30/50
# 52/52 [==============================] - 42s 820ms/step - loss: 0.2268 - accuracy: 0.9045 - val_loss: 0.4234 - val_accuracy: 0.8177
# Epoch 31/50
# 52/52 [==============================] - 42s 815ms/step - loss: 0.2470 - accuracy: 0.8984 - val_loss: 0.3187 - val_accuracy: 0.8803
# Epoch 32/50
# 52/52 [==============================] - 42s 814ms/step - loss: 0.2303 - accuracy: 0.9033 - val_loss: 0.4263 - val_accuracy: 0.8547
# Epoch 33/50
# 52/52 [==============================] - 43s 822ms/step - loss: 0.1798 - accuracy: 0.9278 - val_loss: 0.4245 - val_accuracy: 0.8803
# Epoch 34/50
# 52/52 [==============================] - 43s 834ms/step - loss: 0.2106 - accuracy: 0.9045 - val_loss: 0.4150 - val_accuracy: 0.8718
# Epoch 35/50
# 52/52 [==============================] - 42s 811ms/step - loss: 0.2811 - accuracy: 0.8862 - val_loss: 0.3367 - val_accuracy: 0.8632
# Epoch 36/50
# 52/52 [==============================] - 42s 802ms/step - loss: 0.2481 - accuracy: 0.8923 - val_loss: 0.3675 - val_accuracy: 0.8746
# Epoch 37/50
# 52/52 [==============================] - 41s 800ms/step - loss: 0.1892 - accuracy: 0.9155 - val_loss: 0.3147 - val_accuracy: 0.8718
# Epoch 38/50
# 52/52 [==============================] - 42s 801ms/step - loss: 0.2032 - accuracy: 0.9009 - val_loss: 0.3257 - val_accuracy: 0.8718
# Epoch 39/50
# 52/52 [==============================] - 42s 813ms/step - loss: 0.1980 - accuracy: 0.9192 - val_loss: 0.3213 - val_accuracy: 0.8575
# Epoch 40/50
# 52/52 [==============================] - 42s 800ms/step - loss: 0.1992 - accuracy: 0.9131 - val_loss: 0.2445 - val_accuracy: 0.8632
# Epoch 41/50
# 52/52 [==============================] - 42s 819ms/step - loss: 0.2051 - accuracy: 0.9143 - val_loss: 0.3989 - val_accuracy: 0.8661
# Epoch 42/50
# 52/52 [==============================] - 42s 806ms/step - loss: 0.2342 - accuracy: 0.9033 - val_loss: 0.3343 - val_accuracy: 0.8889
# Epoch 43/50
# 52/52 [==============================] - 42s 807ms/step - loss: 0.1895 - accuracy: 0.9229 - val_loss: 0.4535 - val_accuracy: 0.8234
# Epoch 44/50
# 52/52 [==============================] - 41s 798ms/step - loss: 0.2099 - accuracy: 0.9204 - val_loss: 0.3749 - val_accuracy: 0.8746
# Epoch 45/50
# 52/52 [==============================] - 42s 809ms/step - loss: 0.1879 - accuracy: 0.9204 - val_loss: 0.4017 - val_accuracy: 0.8205
# Epoch 46/50
# 52/52 [==============================] - 42s 804ms/step - loss: 0.2624 - accuracy: 0.8911 - val_loss: 0.4068 - val_accuracy: 0.8319
# Epoch 47/50
# 52/52 [==============================] - 42s 804ms/step - loss: 0.2760 - accuracy: 0.8972 - val_loss: 0.3376 - val_accuracy: 0.8718
# Epoch 48/50
# 52/52 [==============================] - 43s 835ms/step - loss: 0.2657 - accuracy: 0.8898 - val_loss: 0.3636 - val_accuracy: 0.8604
# Epoch 49/50
# 52/52 [==============================] - 43s 828ms/step - loss: 0.1912 - accuracy: 0.9217 - val_loss: 0.3533 - val_accuracy: 0.9003
# Epoch 50/50
# 52/52 [==============================] - 42s 819ms/step - loss: 0.1742 - accuracy: 0.9204 - val_loss: 0.2844 - val_accuracy: 0.9088
# C:\Users\My Computer\.conda\envs\Belajar_env\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # Print model performance

# %%
def print_model_performance(test_gen, print_code=0):
    preds = model.predict(test_gen)
    class_dict = test_gen.class_indices
    labels = test_gen.labels
    file_names = test_gen.filenames
    errors = 0

    for i, p in enumerate(preds):
        pred_index = np.argmax(p)
        true_index = labels[i]
        if pred_index != true_index:
            errors += 1

    accuracy = (1 - errors / len(labels)) * 100
    print(f'Accuracy on the test set is {accuracy:.2f}%')

    if print_code != 0:
        for i in range(min(print_code, errors)):
            print(f'Filename: {file_names[i]}, Predicted Class: {pred_index[i]}, True Class: {true_index[i]}')

    y_true = np.array(labels)
    y_pred = np.argmax(preds, axis=1)

    print("Classification Report:")
    print(classification_report(y_true, y_pred, target_names=list(class_dict.keys())))


print_model_performance(test_gen)
# Out:
# 22/22 [==============================] - 7s 323ms/step
# Accuracy on the test set is 90.03%
# Classification Report:
#                precision    recall  f1-score   support
#
# hama_belalang       0.62      0.72      0.67        32
#     hama_ulat       0.97      0.92      0.95       158
#    sawi_sehat       0.90      0.91      0.90       161
#
#      accuracy                           0.90       351
#     macro avg       0.83      0.85      0.84       351
#  weighted avg       0.91      0.90      0.90       351

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Perbandingan akurasi Training dan validation')
plt.legend(loc=0)
plt.figure()
plt.show()

plt.plot(epochs, loss, 'g', label='Training loss')
plt.plot(epochs, val_loss, 'k', label='Validation loss')
plt.title('Perbandingan loss Training dan validation')
plt.legend(loc=0)
plt.figure()
plt.show()

# %%
print_code=0
preds=model.predict(test_gen) 
print_model_performance( test_gen,print_code )
# Out:
# 22/22 [==============================] - 7s 324ms/step
# 22/22 [==============================] - 7s 323ms/step
# Accuracy on the test set is 88.89%
# Classification Report:
#                precision    recall  f1-score   support
#
# hama_belalang       0.63      0.69      0.66        32
#     hama_ulat       0.97      0.91      0.94       158
#    sawi_sehat       0.87      0.91      0.89       161
#
#      accuracy                           0.89       351
#     macro avg       0.82      0.84      0.83       351
#  weighted avg       0.89      0.89      0.89       351

# %%
Y_pred = model.predict(test_gen)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
print(confusion_matrix(test_gen.classes, y_pred))
# Out:
# 22/22 [==============================] - 8s 348ms/step
# Confusion Matrix
# [[ 23   4   5]
#  [  0 145  13]
#  [ 13   2 146]]
